# %%
import pandas as pd

# %%
#dir_out = 'combined_tables/'
#dir_out = 'combined_tables_snooptr/'
dir_out = 'combined_tables_missing/'

#file_trs = '/expanse/projects/sebat1/miladm/UCSD/LONG_READ_COHORT/TRs_LongTR/FAM/variant_prior/main_df_toR_ZS3_5_7_9_len50_TRmissingness20_fltHomPol_famGT_DELINS_GW.csv'
file_trs = '/expanse/projects/sebat1/miladm/UCSD/LONG_READ_COHORT/TRs_LongTR/FAM/variant_prior/main_df_toR_ZS3_5_7_9_len50_TRmissingness25_fltHomPol_famGT_DELINS_GW.csv'
tr_miss_level = file_trs.split('_TRmissingness')[1].rstrip('_fltHomPol_famGT_DELINS_GW.csv')
print(tr_miss_level)
# Out:
# 25

# %%
#input = 'sbayesr'
input = 'prscs'

# %%
if (input == 'sbayesr'):
    file_prs_asd = '/expanse/projects/sebat1/j3guevar/misc/asd_prs/prs_scripts_combined_analysis/plink.asd.scores.reach_rename.txt'
    file_prs_scz = '/expanse/projects/sebat1/j3guevar/misc/asd_prs/prs_scripts_combined_analysis/plink.scz.scores.reach_rename.txt'
    file_prs_edu = '/expanse/projects/sebat1/j3guevar/misc/asd_prs/prs_scripts_combined_analysis/plink.edu.scores.reach_rename.txt'
elif (input == 'prscs'):
    #FID    IID ALLELE_CT   NAMED_ALLELE_DOSAGE_SUM SCORE1_AVG  SCORE1_SUM
    file_prs_asd = '/expanse/projects/sebat1/miladm/UCSD/LONG_READ_COHORT/PRS/REACH_daner_PGCiPSYCH_loSSC_cleaned_pst_eff_a1_b0.5_phi1e-02_all_chrs.txt.sscore'
    file_prs_scz = '/expanse/projects/sebat1/miladm/UCSD/LONG_READ_COHORT/PRS/REACH_ckqny.scz2snpres_pst_eff_a1_b0.5_phi1e-02_all_chrs.txt.sscore'
    file_prs_edu = '/expanse/projects/sebat1/miladm/UCSD/LONG_READ_COHORT/PRS/REACH_GWAS_EA_excl23andMe_pst_eff_a1_b0.5_phi1e-02_all_chrs.txt.sscore'

rename_samples_dict = {'REACH000236': 'REACH000236_PB', 
                       'REACH000436': 'REACH000436_PB', 
                       'REACH000530': 'REACH000530_PB', 
                       'REACH000531': 'REACH000531_ONT', 
                       'REACH000532': 'REACH000532_ONT'}

df_prs_asd = pd.read_table(file_prs_asd, sep='\t', header=0)
if (input == 'sbayesr'):
    df_prs_asd.columns = ['IID', 'PRS_ASD']
    df_prs_asd = df_prs_asd.loc[df_prs_asd.IID.str.contains('REACH000')]
elif (input == 'prscs'):
    df_prs_asd.columns = ['FID', 'IID', 'ALLELE_CT', 'NAMED_ALLELE_DOSAGE_SUM', 'SCORE1_AVG', 'PRS_ASD']

this_mean = df_prs_asd.PRS_ASD.mean()
this_std = df_prs_asd.PRS_ASD.std()
df_prs_asd['PRS_ASD_Z'] = (df_prs_asd['PRS_ASD'] - this_mean) / this_std
df_prs_asd['IID'] = df_prs_asd.apply(lambda row: rename_samples_dict[row['IID']] 
                                     if row['IID'] in rename_samples_dict else row['IID'], axis=1)
df_prs_asd.set_index('IID', inplace=True)
display(df_prs_asd)


df_prs_scz = pd.read_table(file_prs_scz, sep='\t', header=0)
if (input == 'sbayesr'):
    df_prs_scz.columns = ['IID', 'PRS_SCZ']
    df_prs_scz = df_prs_scz.loc[df_prs_scz.IID.str.contains('REACH000')]
elif (input == 'prscs'):
    df_prs_scz.columns = ['FID', 'IID', 'ALLELE_CT', 'NAMED_ALLELE_DOSAGE_SUM', 'SCORE1_AVG', 'PRS_SCZ']

this_mean = df_prs_scz.PRS_SCZ.mean()
this_std = df_prs_scz.PRS_SCZ.std()
df_prs_scz['PRS_SCZ_Z'] = (df_prs_scz['PRS_SCZ'] - this_mean) / this_std
df_prs_scz['IID'] = df_prs_scz.apply(lambda row: rename_samples_dict[row['IID']] 
                                     if row['IID'] in rename_samples_dict else row['IID'], axis=1)
df_prs_scz.set_index('IID', inplace=True)
display(df_prs_scz)

df_prs_edu = pd.read_table(file_prs_edu, sep='\t', header=0)
if (input == 'sbayesr'):
    df_prs_edu.columns = ['IID', 'PRS_EDU']
    df_prs_edu = df_prs_edu.loc[df_prs_edu.IID.str.contains('REACH000')]
elif (input == 'prscs'):
    df_prs_edu.columns = ['FID', 'IID', 'ALLELE_CT', 'NAMED_ALLELE_DOSAGE_SUM', 'SCORE1_AVG', 'PRS_EDU']

this_mean = df_prs_edu.PRS_EDU.mean()
this_std = df_prs_edu.PRS_EDU.std()
df_prs_edu['PRS_EDU_Z'] = (df_prs_edu['PRS_EDU'] - this_mean) / this_std
df_prs_edu['IID'] = df_prs_edu.apply(lambda row: rename_samples_dict[row['IID']] 
                                     if row['IID'] in rename_samples_dict else row['IID'], axis=1)
df_prs_edu.set_index('IID', inplace=True)
display(df_prs_edu)
# Out:
#              FID  ALLELE_CT  NAMED_ALLELE_DOSAGE_SUM  SCORE1_AVG  PRS_ASD  \
# IID
# REACH000001    0    1644466                   382413    0.000003  5.44642
# REACH000026    0    1644484                   397822    0.000004  6.97789
# REACH000050    0    1644468                   379916    0.000003  5.59728
# REACH000058    0    1644454                   382247    0.000004  7.32853
# REACH000065    0    1644492                   411824    0.000005  8.01366
# ...          ...        ...                      ...         ...      ...
# REACH000772    0    1644340                   377760    0.000004  6.72874
# REACH000773    0    1644310                   377377    0.000004  6.07153
# REACH000774    0    1644376                   379981    0.000004  6.47407
# REACH000775    0    1644404                   379560    0.000004  6.72222
# REACH000776    0    1644390                   378641    0.000003  5.70677
#
#              PRS_ASD_Z
# IID
# REACH000001  -0.971701
# ...

# %%
file_brainspan = '/expanse/projects/sebat1/miladm/UCSD/resources/brainspan_rnaseq/process/gene_list_RPKM_10.csv'
dtype = {'gene_id': str, 'entrez_id': str}
df_br = pd.read_table(file_brainspan, sep=',', header=0, dtype=dtype)
br_flt_10 = df_br.loc[df_br.mean_rpkm>10].gene_symbol.tolist()
br_flt_20 = df_br.loc[df_br.mean_rpkm>20].gene_symbol.tolist()
br_flt_30 = df_br.loc[df_br.mean_rpkm>30].gene_symbol.tolist()
br_flt_40 = df_br.loc[df_br.mean_rpkm>40].gene_symbol.tolist()
br_flt_50 = df_br.loc[df_br.mean_rpkm>50].gene_symbol.tolist()
print(df_br.shape)
print(len(br_flt_10))
print(len(br_flt_20))
print(len(br_flt_30))
print(len(br_flt_40))
print(len(br_flt_50))
# Out:
# (5824, 32)
# 5824
# 3045
# 1983
# 1392
# 1078

# %%
### previously discovered variants
file_fdr = '/expanse/projects/sebat1/miladm/UCSD/resources/ASD_TADA_2022/fdr_pvals_tada.tsv'
df_fdr = pd.read_table(file_fdr, sep='\t', header=0, index_col=None)
print('df_fdr:')
display(df_fdr)
asd_genes = df_fdr.loc[df_fdr.FDR_TADA_ASD <= 0.05].gene_gencodeV33.tolist()
dd_genes = df_fdr.loc[df_fdr.FDR_TADA_DD <= 0.05].gene_gencodeV33.tolist()
ndd_genes = df_fdr.loc[df_fdr.FDR_TADA_NDD <= 0.05].gene_gencodeV33.tolist()
print(f'asd: {len(asd_genes)}')
#print(f'asd: {(asd_genes)}')
print(f'dd: {len(dd_genes)}')
print(f'ndd: {len(ndd_genes)}')

file_pli = '/expanse/projects/sebat1/miladm/UCSD/resources/gnomAD/v4/Constraint/gene_max_pli.tsv'
df_pli = pd.read_table(file_pli, sep='\t', header=0, index_col=None).set_index('gene')
print('df_pli:')
display(df_pli)

file_lf = '/expanse/projects/sebat1/miladm/UCSD/resources/gnomAD/v4/Constraint/gene_min_loeuf.tsv'
df_lf = pd.read_table(file_lf, sep='\t', header=0, index_col=None).set_index('gene')
print('df_lf:')
display(df_lf)

print('dnLOF and dnMIS SNV/indels')
file_dn_snv = '/expanse/projects/sebat1/miladm/UCSD/resources/Antaki_2022/Antaki2022_supplementary_tables_ST5.tsv'
df_dn_snv = pd.read_table(file_dn_snv, sep='\t', header=0, index_col=None, keep_default_na=False)
df_dn_snv['PLI'] = df_dn_snv.gene.map(df_pli['lof.pLI'])
df_dn_snv['LOEUF'] = df_dn_snv.gene.map(df_lf['lof.oe_ci.upper'])
df_dn_snv['FDR_ASD'] = df_dn_snv.gene.map(lambda x: 1 if x in asd_genes else 0)
df_dn_snv['FDR_DD'] = df_dn_snv.gene.map(lambda x: 1 if x in dd_genes else 0)
df_dn_snv['FDR_NDD'] = df_dn_snv.gene.map(lambda x: 1 if x in ndd_genes else 0)
df_dn_snv['DEV_BR_GENE_10'] = df_dn_snv.gene.map(lambda x: 1 if x in br_flt_10 else 0)
df_dn_snv = df_dn_snv.loc[(df_dn_snv.iid.str.contains('REACH'))]
display(df_dn_snv.shape)
print(f" fdr asd: {df_dn_snv['FDR_ASD'].sum()}")
print(f" fdr dd: {df_dn_snv['FDR_DD'].sum()}")
print(f" fdr ndd: {df_dn_snv['FDR_NDD'].sum()}")
print(f" fdr brain genes: {df_dn_snv['DEV_BR_GENE_10'].sum()}")
print('df_dn_snv:')
display(df_dn_snv)
this_df_dn = df_dn_snv[['loss_of_function', 'missense', 'PLI', 'LOEUF', 'FDR_ASD', 'FDR_DD', 'FDR_NDD', 'DEV_BR_GENE_10']].copy()
this_df_dn['samples_all'] = df_dn_snv['iid']
# filter constraint genes
this_df_dn = this_df_dn.loc[((this_df_dn.PLI>=0.9) | (this_df_dn.LOEUF<=0.37) | 
                             (this_df_dn.FDR_ASD==1) | (this_df_dn.FDR_DD==1) | (this_df_dn.FDR_NDD==1))]
print('this_df_dn:')
display(this_df_dn.shape)
display(this_df_dn)

this_df_dnL = this_df_dn.loc[this_df_dn.loss_of_function==1]
this_df_dnM = this_df_dn.loc[this_df_dn.missense==1]
print('this_df_dnL:')
display(this_df_dnL.shape)
print('this_df_dnM:')
display(this_df_dnM.shape)

print('inhLOF SNV/indels')
file_inh_snv = '/expanse/projects/sebat1/miladm/UCSD/resources/Antaki_2022/Antaki2022_supplementary_tables_ST8.tsv'
df_inh_snv = pd.read_table(file_inh_snv, sep='\t', header=0, index_col=None, keep_default_na=False)
df_inh_snv['PLI'] = df_inh_snv.gene.map(df_pli['lof.pLI'])
df_inh_snv['LOEUF'] = df_inh_snv.gene.map(df_lf['lof.oe_ci.upper'])
df_inh_snv['FDR_ASD'] = df_inh_snv.gene.map(lambda x: 1 if x in asd_genes else 0)
df_inh_snv['FDR_DD'] = df_inh_snv.gene.map(lambda x: 1 if x in dd_genes else 0)
df_inh_snv['FDR_NDD'] = df_inh_snv.gene.map(lambda x: 1 if x in ndd_genes else 0)
df_inh_snv['DEV_BR_GENE_10'] = df_inh_snv.gene.map(lambda x: 1 if x in br_flt_10 else 0)
df_inh_snv = df_inh_snv.loc[(df_inh_snv.cases.str.contains('REACH')) | ((df_inh_snv.controls.str.contains('REACH')))]
display(df_inh_snv.shape)
print(f" fdr asd: {df_inh_snv['FDR_ASD'].sum()}")
print(f" fdr dd: {df_inh_snv['FDR_DD'].sum()}")
print(f" fdr ndd: {df_inh_snv['FDR_NDD'].sum()}")
print(f" fdr brain genes: {df_inh_snv['DEV_BR_GENE_10'].sum()}")
print('df_inh_snv:')
display(df_inh_snv)
this_df_inh = df_inh_snv[['PLI', 'LOEUF', 'FDR_ASD', 'FDR_DD', 'FDR_NDD', 'DEV_BR_GENE_10']].copy()
this_df_inh['samples_all'] = df_inh_snv.apply(lambda row: ','.join([x for x in [row.cases, row.controls, 
                                                                         row.fathers, row.mothers] if x != '']), axis=1)
# filter constraint genes
this_df_inh = this_df_inh.loc[((this_df_inh.PLI>=0.9) | (this_df_inh.LOEUF<=0.37) | 
                             (this_df_inh.FDR_ASD==1) | (this_df_inh.FDR_DD==1) | (this_df_inh.FDR_NDD==1))]
print('this_df_inh:')
display(this_df_inh.shape)
display(this_df_inh)

print('Merged denovo and inheritted one row per sample')
#this_df_dn_inh = pd.concat([this_df_dn, this_df_inh], axis=0, ignore_index=True)
this_df_dn_inh = pd.concat([this_df_dnL, this_df_inh], axis=0, ignore_index=True)
this_df_dn_inh['samples_all'] = this_df_dn_inh.samples_all.str.split(',')
this_df_dn_inh = this_df_dn_inh.explode('samples_all')

rename_samples_dict = {'REACH000236': 'REACH000236_PB', 
                       'REACH000436': 'REACH000436_PB', 
                       'REACH000530': 'REACH000530_PB', 
                       'REACH000531': 'REACH000531_ONT', 
                       'REACH000532': 'REACH000532_ONT'}
this_df_dn_inh['samples_all'] = this_df_dn_inh.apply(lambda row: rename_samples_dict[row['samples_all']] 
                                             if row['samples_all'] in rename_samples_dict else row['samples_all'], axis=1)

print('this_df_dn_inh:')
display(this_df_dn_inh)
this_df_dn_inh.to_csv('investigate.tsv', sep='\t', index=None)
# Out:
# df_fdr:
#       gene_gencodeV33  FDR_TADA_ASD  FDR_TADA_DD  FDR_TADA_NDD  p_TADA_ASD  \
# 0             SYNGAP1      0.000000     0.000000      0.000000    0.000000
# 1                CHD8      0.000000     0.000000      0.000000    0.000000
# 2                ADNP      0.000000     0.000000      0.000000    0.000000
# 3              SHANK3      0.000000     0.000000      0.000000    0.000000
# 4               SCN2A      0.000000     0.000000      0.000000    0.000000
# ...               ...           ...          ...           ...         ...
# 18123            PSG2      0.911036     0.913971      0.879392    0.999770
# 18124             NaN      0.911038     0.913973      0.879395    0.999827
# 18125            GJB2      0.911040     0.913975      0.879399    0.999885
# 18126            PSG1      0.911042     0.913979      0.879403    0.999942
# 18127          NBPF10      0.911044     0.913981      0.879407    1.000000
#
#        p_TADA_DD  p_TADA_NDD
# ...

# %%
#file_svss = ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES.csv',    'main_df_toR_freq05_LRIL_SQ30_SAMPLES_SQ30_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD3_SAMPLES_AD3_SAMPLES.csv',    'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD3_SAMPLES_SQ20_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_SQ20_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES.csv',    'main_df_toR_freq05_LRIL_SQ40_SAMPLES_SQ40_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD4_SAMPLES.csv',    'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_SQ20_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_SQ20_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES.csv',    'main_df_toR_freq05_LRIL_SQ50_SAMPLES_SQ50_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD5_SAMPLES.csv',    'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_SQ20_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_SQ20_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_SQ60_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_SQ20_SAMPLES.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ70_SAMPLES_SQ20_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_SQ20_SAMPLES.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_SQ70_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD3_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD3_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD3_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD3_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ40_SAMPLES_SQ30_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ50_SAMPLES_SQ30_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ60_SAMPLES_SQ30_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ70_SAMPLES_SQ30_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ40_SAMPLES_SQ40_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ50_SAMPLES_SQ40_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ60_SAMPLES_SQ40_SAMPLES.csv'
#,'main_df_toR_freq05_LRIL_SQ70_SAMPLES_SQ40_SAMPLES.csv']

#file_svss = ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES_INSDUP.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES_INSDUP.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES_INSDUP.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES_INSDUP.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES_INSDUP.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES_INSDUP.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES_INSDUP.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES_INSDUP.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES_INSDUP.csv']

#file_svss = ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES_DEL.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES_DEL.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES_DEL.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES_DEL.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES_DEL.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES_DEL.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES_DEL.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES_DEL.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES_DEL.csv']

#file_svss = ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES.csv'] + ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES_HP12.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES_HP12.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES_HP12.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES_HP12.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES_HP12.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES_HP12.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES_HP12.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES_HP12.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES_HP12.csv'] + ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES_NCOM.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES_NCOM.csv',
#'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES_NCOM.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES_NCOM.csv',
#'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES_NCOM.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES_NCOM.csv',
#'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES_NCOM.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES_NCOM.csv',
#'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES_NCOM.csv']

file_svss = ['main_df_toR_freq05_LRIL_AD3_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',   'main_df_toR_freq05_LRIL_SQ40_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',
'main_df_toR_freq05_LRIL_AD4_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',   'main_df_toR_freq05_LRIL_SQ50_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',
'main_df_toR_freq05_LRIL_AD5_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',   'main_df_toR_freq05_LRIL_SQ60_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',
'main_df_toR_freq05_LRIL_SQ20_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',  'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES_DELINS_GW.csv',
'main_df_toR_freq05_LRIL_SQ30_SAMPLES_AD2_SAMPLES_DELINS_GW.csv']

#file_svs = 'main_df_toR_freq05_LRIL_SQ70_SAMPLES_AD2_SAMPLES.csv'

for file_svs in file_svss:
    print('+'*40)
    file_suf = file_svs.lstrip('main_df_toR_freq05_LRIL_').rstrip('.csv')
    df_svs = pd.read_table(file_svs, sep=',', header=0)
    #display(df_svs)
    
    cols_count_svs = [x for x in list(df_svs.columns) if x.startswith('count_')]
    print(f'len cols_count_svs: {len(cols_count_svs)}')
    
    df_trs = pd.read_table(file_trs, sep=',', header=0)
    #display(df_trs)
    
    cols_count_trs = [x for x in list(df_trs.columns) if x.startswith('count_')]
    print(f'len cols_count_trs: {len(cols_count_trs)}')
    
    #set_int = set(cols_count_svs).intersection(set(cols_count_trs))
    #print(f'len set_int: {len(set_int)}')
    
    df_combined = df_svs.merge(df_trs[['iid']+cols_count_trs])
    df_combined['PRS_ASD_Z'] = df_combined.iid.map(df_prs_asd.PRS_ASD_Z)
    df_combined['PRS_SCZ_Z'] = df_combined.iid.map(df_prs_scz.PRS_SCZ_Z)
    df_combined['PRS_EDU_Z'] = df_combined.iid.map(df_prs_edu.PRS_EDU_Z)
    
    count_col = []
    samples_dn_inh = this_df_dn_inh.samples_all.tolist()
    for sample in df_combined.iid:
        count_col.append(samples_dn_inh.count(sample))
    df_combined['count_dnlof_inhlof'] = count_col
    #print('df_combined:')
    #display(df_combined)
    print(f'sum of all dn/inh: {df_combined.count_dnlof_inhlof.sum()}')
    print(f'C, case, carrier: {df_combined.loc[(df_combined.rel=="C")&(df_combined.Affected=="Yes")&(df_combined.count_dnlof_inhlof>0)].shape}')
    print(f'C, case, non-carrier: {df_combined.loc[(df_combined.rel=="C")&(df_combined.Affected=="Yes")&(df_combined.count_dnlof_inhlof==0)].shape}')
    print(f'C, control, carrier: {df_combined.loc[(df_combined.rel=="C")&(df_combined.Affected=="No")&(df_combined.count_dnlof_inhlof>0)].shape}')
    print(f'C, control, non-carrier: {df_combined.loc[(df_combined.rel=="C")&(df_combined.Affected=="No")&(df_combined.count_dnlof_inhlof==0)].shape}')
    print(f'P, case, carrier: {df_combined.loc[(df_combined.rel=="P")&(df_combined.Affected=="Yes")&(df_combined.count_dnlof_inhlof>0)].shape}')
    print(f'P, case, non-carrier: {df_combined.loc[(df_combined.rel=="P")&(df_combined.Affected=="Yes")&(df_combined.count_dnlof_inhlof==0)].shape}')
    print(f'P, control, carrier: {df_combined.loc[(df_combined.rel=="P")&(df_combined.Affected=="No")&(df_combined.count_dnlof_inhlof>0)].shape}')
    print(f'P, control, non-carrier: {df_combined.loc[(df_combined.rel=="P")&(df_combined.Affected=="No")&(df_combined.count_dnlof_inhlof==0)].shape}')
    
    if (input == 'sbayesr'):
        file_out = dir_out + 'combined_svs_trs_snvs_prs_pc_sbayesr_' + file_suf + '_' + 'TRmissingness' + tr_miss_level + '_fltHomPol_famGT.csv'
    elif (input == 'prscs'):
        file_out = dir_out + 'combined_svs_trs_snvs_prs_pc_prscs_' + file_suf + '_' + 'TRmissingness' + tr_miss_level + '_fltHomPol_famGT.csv'
    print(file_out)
    df_combined.to_csv(file_out, sep=',', header=True, index=False)
# Out:
# ++++++++++++++++++++++++++++++++++++++++
# len cols_count_svs: 375
# len cols_count_trs: 4896
# sum of all dn/inh: 87
# C, case, carrier: (30, 5323)
# C, case, non-carrier: (46, 5323)
# C, control, carrier: (8, 5323)
# C, control, non-carrier: (33, 5323)
# P, case, carrier: (0, 5323)
# P, case, non-carrier: (4, 5323)
# P, control, carrier: (30, 5323)
# P, control, non-carrier: (92, 5323)
# combined_tables_missing/combined_svs_trs_snvs_prs_pc_prscs_AD3_SAMPLES_AD2_SAMPLES_DELINS_GW_TRmissingness25_fltHomPol_famGT.csv
# ++++++++++++++++++++++++++++++++++++++++
# len cols_count_svs: 375
# len cols_count_trs: 4896
# sum of all dn/inh: 87
# C, case, carrier: (30, 5323)
# C, case, non-carrier: (46, 5323)
# C, control, carrier: (8, 5323)
# C, control, non-carrier: (33, 5323)
# P, case, carrier: (0, 5323)
# P, case, non-carrier: (4, 5323)
# P, control, carrier: (30, 5323)
# P, control, non-carrier: (92, 5323)
# ...
