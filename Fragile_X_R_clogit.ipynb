# %%
library(survival)
library(ggplot2)
library(dplyr)
library(reshape2)
library(stringr)
# Out:
# Warning message:
# “package ‘survival’ was built under R version 4.0.5”
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.5”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.5”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘reshape2’ was built under R version 4.0.5”
# Warning message:
# “package ‘stringr’ was built under R version 4.0.5”

# %%
file_main = 'fragile_x_tables/methylation_table.tsv'
df_main <- read.table(file_main, header = TRUE, sep = "\t")
print(dim(df_main))
head(df_main)

df_main_female = df_main[df_main$sex==2,]
print(dim(df_main_female))
head(df_main_female)

df_main_male = df_main[df_main$sex==1,]
print(dim(df_main_male))
head(df_main_male)
# Out:
# [1] 218  26
#   subject     hp_tag fid   Affected Phenotype sex coverage rel hp_rep_fmr1
# 1 REACH000058 hm     F0058 Yes      1         1   6.19     C   37
# 2 REACH000086 hm     F0078 Yes      1         1   2.70     C   30
# 3 REACH000087 h1     F0078 No       0         2   2.75     M   30
# 4 REACH000087 h2     F0078 No       0         2   2.75     M   30
# 5 REACH000088 hm     F0078 No       0         1   3.30     D   31
# 6 REACH000089 h1     F0078 Yes      1         2   3.27     C   30
#   num_reads_fmr1 ⋯ PC1          PC2          PC3          PC4
# 1 7              ⋯  0.002421759 -0.009216429 -0.007762021  0.073817110
# 2 1              ⋯  0.044785250  0.038064880  0.054606420  0.014648300
# 3 1              ⋯  0.129968000  0.080386740  0.132056000  0.029583190
# 4 4              ⋯  0.129968000  0.080386740  0.132056000  0.029583190
# 5 2              ⋯ -0.034479970 -0.003222265 -0.007194412 -0.001005916
# 6 2              ⋯  0.049879690  0.047204300  0.069404520  0.015002170
#   PC5         PC6         PC7          PC8         PC9          PC10
# 1 0.015719580 0.006302990  0.055402580 -0.03832684 -0.011381190  0.032497550
# 2 0.018967260 0.014095430 -0.008568837  0.01083623  0.005924319 -0.012542530
# 3 0.020155760 0.007971487 -0.002382853  0.01446834  0.006253360 -0.018303350
# 4 0.020155760 0.007971487 -0.002382853  0.01446834  0.006253360 -0.018303350
# 5 0.007011618 0.020830010 -0.009793191  0.01528981 -0.020904860 -0.000666553
# 6 0.011334000 0.011519280 -0.001072494  0.01441817 -0.017609010 -0.005675884
# [1] 116  26
#   subject     hp_tag fid   Affected Phenotype sex coverage rel hp_rep_fmr1
# 3 REACH000087 h1     F0078 No       0         2   2.75     M   30
# 4 REACH000087 h2     F0078 No       0         2   2.75     M   30
# 6 REACH000089 h1     F0078 Yes      1         2   3.27     C   30
# 7 REACH000089 h2     F0078 Yes      1         2   3.27     C   30
# 8 REACH000092 h1     F0081 Yes      1         2   4.89     C   31
# 9 REACH000092 h2     F0081 Yes      1         2   4.89     C   29
#   num_reads_fmr1 ⋯ PC1         PC2          PC3          PC4
# 3 1              ⋯  0.12996800  0.080386740  0.132056000 0.029583190
# 4 4              ⋯  0.12996800  0.080386740  0.132056000 0.029583190
# 6 2              ⋯  0.04987969  0.047204300  0.069404520 0.015002170
# 7 3              ⋯  0.04987969  0.047204300  0.069404520 0.015002170
# 8 1              ⋯ -0.02851068 -0.001001894 -0.001920863 0.004426021
# 9 5              ⋯ -0.02851068 -0.001001894 -0.001920863 0.004426021
#   PC5          PC6         PC7          PC8         PC9         PC10
# 3  0.020155760 0.007971487 -0.002382853 0.014468340  0.00625336 -0.018303350
# 4  0.020155760 0.007971487 -0.002382853 0.014468340  0.00625336 -0.018303350
# 6  0.011334000 0.011519280 -0.001072494 0.014418170 -0.01760901 -0.005675884
# 7  0.011334000 0.011519280 -0.001072494 0.014418170 -0.01760901 -0.005675884
# 8 -0.001890728 0.006074058  0.027473970 0.004610759  0.01559551  0.030866010
# 9 -0.001890728 0.006074058  0.027473970 0.004610759  0.01559551  0.030866010
# [1] 102  26
#    subject     hp_tag fid   Affected Phenotype sex coverage rel hp_rep_fmr1
# 1  REACH000058 hm     F0058 Yes      1         1   6.19     C   37
# 2  REACH000086 hm     F0078 Yes      1         1   2.70     C   30
# 5  REACH000088 hm     F0078 No       0         1   3.30     D   31
# 11 REACH000094 hm     F0081 No       0         1   4.94     D   31
# 12 REACH000097 hm     F0083 Yes      1         1   5.82     C   30
# 14 REACH000099 hm     F0083 No       0         1   5.02     D   31
#    num_reads_fmr1 ⋯ PC1          PC2          PC3          PC4
# 1  7              ⋯  0.002421759 -0.009216429 -0.007762021  0.073817110
# 2  1              ⋯  0.044785250  0.038064880  0.054606420  0.014648300
# 5  2              ⋯ -0.034479970 -0.003222265 -0.007194412 -0.001005916
# 11 1              ⋯ -0.028621930 -0.006658122 -0.005912947  0.004358670
# 12 1              ⋯  0.095793110  0.052887850  0.100821100  0.030144220
# 14 1              ⋯ -0.003588312 -0.023366380 -0.000886756  0.048459450
#    PC5         PC6         PC7          PC8          PC9          PC10
# 1  0.015719580 0.006302990  0.055402580 -0.038326840 -0.011381190  0.032497550
# 2  0.018967260 0.014095430 -0.008568837  0.010836230  0.005924319 -0.012542530
# 5  0.007011618 0.020830010 -0.009793191  0.015289810 -0.020904860 -0.000666553
# 11 0.000023400 0.011374000  0.031337980  0.008001811  0.023594750  0.034265810
# 12 0.008287742 0.001422071 -0.001622091 -0.001162636  0.009583179 -0.013378190
# 14 0.014162230 0.002861614  0.002278807  0.005612425  0.010264340 -0.027054970

# %%
### phenotype as function of FMR1 repeat length
print('combined')
formula = as.formula('Phenotype ~ hp_rep_fmr1 + PC1 + PC2 + PC3 + strata(fid)')
#formula = as.formula('Phenotype ~ hp_rep_fmr1 + strata(fid)')
model <- clogit(formula, data = df_main)
print(summary(model))
    
print('female')
female_formula = as.formula('Phenotype ~ hp_rep_fmr1 + PC1 + PC2 + PC3 + strata(fid)')
#female_formula = as.formula('Phenotype ~ hp_rep_fmr1 + strata(fid)')
female_model <- clogit(female_formula, data = df_main_female)
print(summary(female_model))

print('male')
male_formula = as.formula('Phenotype ~ hp_rep_fmr1 + PC1 + PC2 + PC3 + strata(fid)')
#male_formula = as.formula('Phenotype ~ hp_rep_fmr1 + strata(fid)')
male_model <- clogit(male_formula, data = df_main_male)
print(summary(male_model))
# Out:
# [1] "combined"
# Call:
# coxph(formula = Surv(rep(1, 218L), Phenotype) ~ hp_rep_fmr1 +
#     PC1 + PC2 + PC3 + strata(fid), data = df_main, method = "exact")
#
#   n= 218, number of events= 67
#
#                 coef exp(coef) se(coef)      z Pr(>|z|)
# hp_rep_fmr1  0.02649   1.02684  0.04840  0.547    0.584
# PC1          1.88475   6.58470 11.42573  0.165    0.869
# PC2         -2.16951   0.11423 11.62468 -0.187    0.852
# PC3          3.59654  36.47180  6.89826  0.521    0.602
#
#             exp(coef) exp(-coef) lower .95 upper .95
# hp_rep_fmr1    1.0268    0.97386 9.339e-01 1.129e+00
# PC1            6.5847    0.15187 1.239e-09 3.501e+10
# PC2            0.1142    8.75397 1.455e-11 8.969e+08
# PC3           36.4718    0.02742 4.899e-05 2.715e+07
#
# Concordance= 0.578  (se = 0.065 )
# Likelihood ratio test= 0.89  on 4 df,   p=0.9
# Wald test            = 0.85  on 4 df,   p=0.9
# Score (logrank) test = 0.87  on 4 df,   p=0.9
#
# [1] "female"
# Call:
# coxph(formula = Surv(rep(1, 116L), Phenotype) ~ hp_rep_fmr1 +
#     PC1 + PC2 + PC3 + strata(fid), data = df_main_female, method = "exact")
#
#   n= 116, number of events= 23
#
#                    coef   exp(coef)    se(coef)      z Pr(>|z|)
# hp_rep_fmr1   3.891e-02   1.040e+00   9.100e-02  0.428   0.6690
# PC1          -7.616e+01   8.394e-34   7.107e+01 -1.072   0.2839
# PC2          -5.159e+02  8.462e-225   2.904e+02 -1.777   0.0756 .
# PC3           3.368e+02  1.824e+146   1.444e+02  2.332   0.0197 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#              exp(coef) exp(-coef) lower .95  upper .95
# hp_rep_fmr1  1.040e+00  9.618e-01 8.698e-01  1.243e+00
# PC1          8.394e-34  1.191e+33 2.660e-94  2.648e+27
# PC2         8.462e-225 1.182e+224 0.000e+00  1.377e+23
# PC3         1.824e+146 5.482e-147 2.201e+23 1.512e+269
#
# Concordance= 0.737  (se = 0.143 )
# Likelihood ratio test= 9.76  on 4 df,   p=0.04
# Wald test            = 5.89  on 4 df,   p=0.2
# Score (logrank) test = 4.41  on 4 df,   p=0.4
#
# [1] "male"
# Call:
# coxph(formula = Surv(rep(1, 102L), Phenotype) ~ hp_rep_fmr1 +
#     PC1 + PC2 + PC3 + strata(fid), data = df_main_male, method = "exact")
#
#   n= 102, number of events= 44
#
#                   coef  exp(coef)   se(coef)      z Pr(>|z|)
# hp_rep_fmr1 -2.869e-03  9.971e-01  7.286e-02 -0.039    0.969
# PC1          5.911e-02  1.061e+00  1.967e+01  0.003    0.998
# PC2         -3.690e+01  9.384e-17  3.684e+01 -1.002    0.316
# PC3          2.608e+01  2.125e+11  3.189e+01  0.818    0.413
#
#             exp(coef) exp(-coef) lower .95 upper .95
# hp_rep_fmr1 9.971e-01  1.003e+00 8.644e-01 1.150e+00
# PC1         1.061e+00  9.426e-01 1.918e-17 5.868e+16
# PC2         9.384e-17  1.066e+16 4.135e-48 2.130e+15
# PC3         2.125e+11  4.705e-12 1.513e-16 2.986e+38
#
# Concordance= 0.455  (se = 0.116 )
# Likelihood ratio test= 2.36  on 4 df,   p=0.7
# Wald test            = 1.25  on 4 df,   p=0.9
# Score (logrank) test = 1.86  on 4 df,   p=0.8

# %%
colnames(df_main)
# Out:
#  [1] "subject"                      "hp_tag"
#  [3] "fid"                          "Affected"
#  [5] "Phenotype"                    "sex"
#  [7] "coverage"                     "rel"
#  [9] "hp_rep_fmr1"                  "num_reads_fmr1"
# [11] "methylation_mean_fmr1"        "methylation_mean_binary_fmr1"
# [13] "hp_rep_xci"                   "num_reads_xci"
# [15] "methylation_mean_xci"         "methylation_mean_binary_xci"
# [17] "PC1"                          "PC2"
# [19] "PC3"                          "PC4"
# [21] "PC5"                          "PC6"
# [23] "PC7"                          "PC8"
# [25] "PC9"                          "PC10"

# %%
### phenotype as function of FMR1 methylation
print('combined')
formula = as.formula('Phenotype ~ methylation_mean_binary_fmr1 + PC1 + PC2 + PC3 + strata(fid)')
#formula = as.formula('Phenotype ~ hp_rep_fmr1 + strata(fid)')
model <- clogit(formula, data = df_main)
print(summary(model))
    
print('female')
female_formula = as.formula('Phenotype ~ methylation_mean_binary_fmr1 + PC1 + PC2 + PC3 + strata(fid)')
#female_formula = as.formula('Phenotype ~ hp_rep_fmr1 + strata(fid)')
female_model <- clogit(female_formula, data = df_main_female)
print(summary(female_model))

print('male')
male_formula = as.formula('Phenotype ~ methylation_mean_binary_fmr1 + PC1 + PC2 + PC3 + strata(fid)')
#male_formula = as.formula('Phenotype ~ hp_rep_fmr1 + strata(fid)')
male_model <- clogit(male_formula, data = df_main_male)
print(summary(male_model))
# Out:
# [1] "combined"
# Call:
# coxph(formula = Surv(rep(1, 218L), Phenotype) ~ methylation_mean_binary_fmr1 +
#     PC1 + PC2 + PC3 + strata(fid), data = df_main, method = "exact")
#
#   n= 218, number of events= 67
#
#                                 coef exp(coef) se(coef)      z Pr(>|z|)
# methylation_mean_binary_fmr1 -0.5657    0.5680   0.5042 -1.122    0.262
# PC1                           2.0147    7.4986  11.4421  0.176    0.860
# PC2                          -2.1688    0.1143  11.5930 -0.187    0.852
# PC3                           3.4517   31.5540   6.7838  0.509    0.611
#
#                              exp(coef) exp(-coef) lower .95 upper .95
# methylation_mean_binary_fmr1    0.5680    1.76066 2.114e-01 1.526e+00
# PC1                             7.4986    0.13336 1.366e-09 4.116e+10
# PC2                             0.1143    8.74740 1.549e-11 8.435e+08
# PC3                            31.5540    0.03169 5.305e-05 1.877e+07
#
# Concordance= 0.556  (se = 0.063 )
# Likelihood ratio test= 1.89  on 4 df,   p=0.8
# Wald test            = 1.81  on 4 df,   p=0.8
# Score (logrank) test = 1.85  on 4 df,   p=0.8
#
# [1] "female"
# Call:
# coxph(formula = Surv(rep(1, 116L), Phenotype) ~ methylation_mean_binary_fmr1 +
#     PC1 + PC2 + PC3 + strata(fid), data = df_main_female, method = "exact")
#
#   n= 116, number of events= 23
#
#                                     coef   exp(coef)    se(coef)      z
# methylation_mean_binary_fmr1   1.298e+00   3.660e+00   1.351e+00  0.960
# PC1                           -8.334e+01   6.380e-37   7.465e+01 -1.116
# PC2                           -5.633e+02  2.325e-245   2.913e+02 -1.934
# PC3                            3.732e+02  1.208e+162   1.497e+02  2.492
#                              Pr(>|z|)
# methylation_mean_binary_fmr1   0.3370
# PC1                            0.2642
# PC2                            0.0531 .
# PC3                            0.0127 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#                               exp(coef) exp(-coef)  lower .95  upper .95
# methylation_mean_binary_fmr1  3.660e+00  2.732e-01  2.590e-01  5.173e+01
# PC1                           6.380e-37  1.567e+36 1.843e-100  2.209e+27
# PC2                          2.325e-245 4.301e+244  0.000e+00  2.000e+03
# PC3                          1.208e+162 8.281e-163  4.145e+34 3.518e+289
#
# Concordance= 0.737  (se = 0.143 )
# Likelihood ratio test= 10.57  on 4 df,   p=0.03
# Wald test            = 6.45  on 4 df,   p=0.2
# Score (logrank) test = 4.4  on 4 df,   p=0.4
#
# [1] "male"
# Call:
# coxph(formula = Surv(rep(1, 102L), Phenotype) ~ methylation_mean_binary_fmr1 +
#     PC1 + PC2 + PC3 + strata(fid), data = df_main_male, method = "exact")
#
#   n= 102, number of events= 44
#
#                                    coef  exp(coef)   se(coef)      z Pr(>|z|)
# methylation_mean_binary_fmr1         NA         NA  0.000e+00     NA       NA
# PC1                           7.783e-02  1.081e+00  1.967e+01  0.004    0.997
# PC2                          -3.673e+01  1.113e-16  3.650e+01 -1.006    0.314
# PC3                           2.594e+01  1.850e+11  3.162e+01  0.820    0.412
#
#                              exp(coef) exp(-coef) lower .95 upper .95
# methylation_mean_binary_fmr1        NA         NA        NA        NA
# PC1                          1.081e+00  9.251e-01 1.936e-17 6.034e+16
# PC2                          1.113e-16  8.987e+15 9.458e-48 1.309e+15
# PC3                          1.850e+11  5.405e-12 2.252e-16 1.520e+38
#
# Concordance= 0.432  (se = 0.116 )
# Likelihood ratio test= 2.35  on 3 df,   p=0.5
# Wald test            = 1.25  on 3 df,   p=0.7
# Score (logrank) test = 1.86  on 3 df,   p=0.6
